# %% [markdown]
# # Fall 2025 DS UCSB Instagram Analysis Dashboard
#
# This notebook cleans and visualizes Instagram engagement data for DS UCSB from the months of August to December 2025. Data was obtained from Meta Business Suite.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

BASE_DIR = Path.cwd()
csv_path = BASE_DIR / "data" / "f25_instagram_data.csv"

df = pd.read_csv(csv_path)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Account username  22 non-null     object
#  1   Account name      22 non-null     object
#  2   Name              22 non-null     object
#  3   Category          22 non-null     object
#  4   Duration (sec)    22 non-null     int64
#  5   Publish time      22 non-null     object
#  6   Post type         22 non-null     object
#  7   Data comment      0 non-null      float64
#  8   Date              22 non-null     object
#  9   Views             22 non-null     int64
#  10  Reach             22 non-null     int64
#  11  Likes             22 non-null     int64
#  12  Shares            22 non-null     int64
#  13  Follows           22 non-null     int64
#  14  Comments          22 non-null     int64
#  15  Saves             22 non-null     int64
# dtypes: float64(1), int64(8), object(7)
# memory usage: 2.9+ KB
